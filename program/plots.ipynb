# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import matplotlib as mpl
from matplotlib import rcParams

mpl.rcParams['figure.figsize'] = (12,12*0.618)

rcParams['font.family'] = 'sans-serif'
#rcParams['font.sans-serif'] = ['Computer Modern Roman']
# Times-Roman

ftsz = 22
lsaPTS = 30
CBAR = 'viridis_r'

# %%
print(plt.style.available)
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'_classic_test', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn', u'seaborn-dark-palette']

# %%
plt.style.use('seaborn-ticks') #seaborn-ticks

# %% [markdown]
# This is the notebook that generates the plots needed for the paper.
# 👻

# %% [markdown]
# ## Discrete Zenith Angles

# %% [markdown]
# For discrete zenith angles, we consider 2 angles and 3 angles cases.

# %% [markdown]
# ### 2 Zenthi Angles

# %% [markdown]
# I can choose `WC1` and `C1` as examples
#
# ```
# spectDBWC1 = {{1, -0.6}, {1, 0.6}}
# spectDBWC2 = {{0.5, -0.6}, {1, 0.6}}
# spectDBWC3 = {{0.1, -0.6}, {1, 0.6}}
# spectDBC1 = {{-1, -0.6}, {1, 0.6}}
# spectDBC2 = {{-0.5, -0.6}, {1, 0.6}}
# spectDBC3 = {{-0.1, -0.6}, {1, 0.6}}
# ```

# %%
# %%bash
# ls data/dr-db-two
# Out:
# lsaMAARODataDBC1.csv
# lsaMAARODataDBWC1.csv
# lsaMZAmRODataDBC1.csv
# lsaMZAmRODataDBWC1.csv
# lsaMZApRODataDBC1.csv
# lsaMZApRODataDBWC1.csv
# spectDBC1DRDBMZAPltData-lower.csv
# spectDBC1DRDBMZAPltData-upper.csv
# spectDBC1DRDBPltData-lower.csv
# spectDBC1DRDBPltData-upper.csv
# spectDBWC1DRDBMZAPltData-lower.csv
# spectDBWC1DRDBMZAPltData-upper.csv
# spectDBWC1DRDBPltData-lower.csv
# spectDBWC1DRDBPltData-upper.csv

# %%
# Import data for WC1 spectrum
spectDBWC1DRDBPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBPltData-upper.csv', delimiter=",")  )
spectDBWC1DRDBPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBPltData-lower.csv', delimiter=",")  )

spectDBWC1DRDBMZAPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBMZAPltData-upper.csv', delimiter=",")  )
spectDBWC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBMZAPltData-lower.csv', delimiter=",")  )

lsaMAARODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMAARODataDBWC1.csv', delimiter=",")  )
lsaMZApRODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZApRODataDBWC1.csv', delimiter=",")  )
lsaMZAmRODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZAmRODataDBWC1.csv', delimiter=",")  )

# Import data for C1 spectrum
spectDBC1DRDBPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBPltData-upper.csv', delimiter=",")  )
spectDBC1DRDBPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBPltData-lower.csv', delimiter=",")  )

spectDBC1DRDBMZAPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBMZAPltData-upper.csv', delimiter=",")  )
spectDBC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBMZAPltData-lower.csv', delimiter=",")  )

lsaMAARODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMAARODataDBC1.csv', delimiter=",")  )
lsaMZApRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZApRODataDBC1.csv', delimiter=",")  )
lsaMZAmRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZAmRODataDBC1.csv', delimiter=",")  )
# Out:
# /Users/leima/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:19: UserWarning: genfromtxt: Empty input file: "data/dr-db-two/lsaMAARODataDBC1.csv"
# /Users/leima/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:20: UserWarning: genfromtxt: Empty input file: "data/dr-db-two/lsaMZApRODataDBC1.csv"
# /Users/leima/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:21: UserWarning: genfromtxt: Empty input file: "data/dr-db-two/lsaMZAmRODataDBC1.csv"

# %%
spectDBWC1DRDBPltDataUpper.shape, \
spectDBWC1DRDBPltDataLower.shape, \
lsaMAARODataDBWC1.shape, \
lsaMZApRODataDBWC1.shape, \
lsaMZAmRODataDBWC1.shape, \
spectDBC1DRDBPltDataUpper.shape, \
spectDBC1DRDBPltDataLower.shape, \
lsaMAARODataDBC1.shape, \
lsaMZApRODataDBC1.shape, \
lsaMZAmRODataDBC1.shape, \
# Out:
# ((2, 333),
#  (2, 9668),
#  (3, 32),
#  (3, 89),
#  (3, 35),
#  (2, 332),
#  (2, 9668),
#  (0,),
#  (0,),
#  (0,))

# %%
spectDBWC1DRDBMAAPlt,  spectDBWC1DRDBMAAPltax = plt.subplots()
plt.plot(spectDBWC1DRDBPltDataUpper[0],spectDBWC1DRDBPltDataUpper[1],'-k')
plt.plot(spectDBWC1DRDBPltDataLower[0],spectDBWC1DRDBPltDataLower[1],'-k')
db3c4seg =1
lsaMAARODataDBWC1Plt =plt.scatter(lsaMAARODataDBWC1[1][::db3c4seg],lsaMAARODataDBWC1[0][::db3c4seg], c=lsaMAARODataDBWC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataDBWC1Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDBWC1DRDBMAAPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDBWC1DRDBMZApPlt,  spectDBWC1DRDBMZApPltax = plt.subplots()
plt.plot(spectDBWC1DRDBMZAPltDataUpper[0],spectDBWC1DRDBMZAPltDataUpper[1],'-k')
plt.plot(spectDBWC1DRDBMZAPltDataLower[0],spectDBWC1DRDBMZAPltDataLower[1],'-k')
db3c4seg=1
lsaMZApRODataDBWC1Plt =plt.scatter(lsaMZApRODataDBWC1[1][::db3c4seg],lsaMZApRODataDBWC1[0][::db3c4seg], c=lsaMZApRODataDBWC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZApRODataDBWC1Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDBWC1DRDBMZApPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDBWC1DRDBMZAmPlt,  spectDBWC1DRDBMZAmPltax = plt.subplots()
plt.plot(spectDBWC1DRDBMZAPltDataUpper[0],spectDBWC1DRDBMZAPltDataUpper[1],'-k')
plt.plot(spectDBWC1DRDBMZAPltDataLower[0],spectDBWC1DRDBMZAPltDataLower[1],'-k')
db3c4seg=1
lsaMZAmRODataDBWC1Plt =plt.scatter(lsaMZAmRODataDBWC1[1][::db3c4seg],lsaMZAmRODataDBWC1[0][::db3c4seg], c=lsaMZAmRODataDBWC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZAmRODataDBWC1Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDBWC1DRDBMZAmPlt.pdf',bbox_inches='tight')
plt.show()

# %%
plt.plot(spectDBC1DRDBPltDataUpper[0],spectDBC1DRDBPltDataUpper[1],'-k')
plt.plot(spectDBC1DRDBPltDataLower[0],spectDBC1DRDBPltDataLower[1],'-k')
lsaMAARODataDBC1Plt =plt.scatter(lsaMAARODataDBC1[1],lsaMAARODataDBC1[0], c=lsaMAARODataDBC1[2], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataDBC1Plt)
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-152-4a1e23754c35> in <module>()
#       1 plt.plot(spectDBC1DRDBPltDataUpper[0],spectDBC1DRDBPltDataUpper[1],'-k')
#       2 plt.plot(spectDBC1DRDBPltDataLower[0],spectDBC1DRDBPltDataLower[1],'-k')
# ----> 3 lsaMAARODataDBC1Plt =plt.scatter(lsaMAARODataDBC1[1],lsaMAARODataDBC1[0], c=lsaMAARODataDBC1[2], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
#       4 plt.colorbar(lsaMAARODataDBC1Plt)
#       5 plt.xlim([-2,2])
#
# IndexError: index 1 is out of bounds for axis 0 with size 0

# %% [markdown]
# ### 3 Zenthi Angles

# %% [markdown]
# ```
# spectDBWC1 = {{1, -0.6}, {1, 0.1}, {1, 0.6}}
# spectDBWC2 = {{0.5, -0.6}, {1, 0.1}, {1, 0.6}}
# spectDBWC3 = {{0.1, -0.6}, {1, 0.1}, {1, 0.6}}
#
# spectDBC1 = {{-1, -0.6}, {1, 0.1}, {1, 0.6}}
# spectDBC2 = {{-0.5, -0.6}, {1, 0.1}, {1, 0.6}}
# spectDBC3 = {{-0.1, -0.6}, {1, 0.1}, {1, 0.6}}
#
# spectDBWC4 = {{0.5, -0.1}, {1, 0.4}, {1, 0.6}}
# spectDBC4 = {{-0.5, 0.1}, {1, 0.4}, {1, 0.6}}
#
# ```

# %%
# %%bash
# ls data/dr-db-three
# Out:
# lsaMAARODataDB3WC1.csv
# spectDB3WC1DRDBMZAPltData-lower.csv
# spectDB3WC1DRDBMZAPltData-mid.csv
# spectDB3WC1DRDBMZAPltData-upper.csv
# spectDB3WC1DRDBPltData-lower.csv
# spectDB3WC1DRDBPltData-mid.csv
# spectDB3WC1DRDBPltData-upper.csv

# %% [markdown]
# #### WC1

# %%
# Import data for WC1 spectrum
spectDB3WC1DRDBPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBPltData-upper.csv', delimiter=",")  )
spectDB3WC1DRDBPltDataMid = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBPltData-mid.csv', delimiter=",")  )
spectDB3WC1DRDBPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBPltData-lower.csv', delimiter=",")  )


spectDB3WC1DRDBMZAPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBMZAPltData-upper.csv', delimiter=",")  )
spectDB3WC1DRDBMZAPltDataMid = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBMZAPltData-mid.csv', delimiter=",")  )
spectDB3WC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC1DRDBMZAPltData-lower.csv', delimiter=",")  )


lsaMAARODataDB3WC1 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMAARODataDB3WC1.csv', delimiter=",")  )

# %%
spectDB3WC1DRDBMAAPlt,  spectDB3WC1DRDBMAAPltax = plt.subplots()
plt.plot(spectDB3WC1DRDBPltDataUpper[0],spectDB3WC1DRDBPltDataUpper[1],'-k')
plt.plot(spectDB3WC1DRDBPltDataMid[0],spectDB3WC1DRDBPltDataMid[1],'-k')
plt.plot(spectDB3WC1DRDBPltDataLower[0],spectDB3WC1DRDBPltDataLower[1],'-k')
db3c4seg = 1
lsaMAARODataDB3WC1Plt =plt.scatter(lsaMAARODataDB3WC1[1][::db3c4seg],lsaMAARODataDB3WC1[0][::db3c4seg], c=lsaMAARODataDB3WC1[2][::db3c4seg], s=10, vmin=0, cmap='viridis', edgecolors='none')
plt.colorbar(lsaMAARODataDB3WC1Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC1DRDBMAAPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3WC1DRDBMZApPlt,  spectDB3WC1DRDBMZApPltax = plt.subplots()
plt.plot(spectDB3WC1DRDBMZAPltDataUpper[0],spectDB3WC1DRDBMZAPltDataUpper[1],'-k')
plt.plot(spectDB3WC1DRDBMZAPltDataMid[0],spectDB3WC1DRDBMZAPltDataMid[1],'-k')
plt.plot(spectDB3WC1DRDBMZAPltDataLower[0],spectDB3WC1DRDBMZAPltDataLower[1],'-k')
# lsaMZApRODataDBWC1Plt =plt.scatter(lsaMZApRODataDBWC1[1][::10],lsaMZApRODataDBWC1[0][::10], c=lsaMZApRODataDBWC1[2][::10], s=10, vmin=0, cmap='viridis', edgecolors='none')
# plt.colorbar(lsaMZApRODataDBWC1Plt)
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC1DRDBMZApPlt.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### C4

# %%
# C4

spectDB3C4DRDBMAAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3C4DRDBMAAPltData.csv', delimiter=",")  )
spectDB3C4DRDBMZAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3C4DRDBMZAPltData.csv', delimiter=",")  )
lsaMAARODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMAARODataDB3C4.csv', delimiter=",")  )
lsaMZApRODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZApRODataDB3C4.csv', delimiter=",")  )
lsaMZAmRODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZAmRODataDB3C4.csv', delimiter=",")  )

# %%
spectDB3C4DRDBMAAPlt,  spectDB3C4DRDBMAAPltax = plt.subplots()
plt.plot(spectDB3C4DRDBMAAPltData[0],spectDB3C4DRDBMAAPltData[1],'.k')
db3c4seg = 3;
lsaMAARODataDB3C4Plt =plt.scatter(lsaMAARODataDB3C4[1][::db3c4seg],lsaMAARODataDB3C4[0][::db3c4seg], c=lsaMAARODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataDB3C4Plt)
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3C4DRDBMAAPlt.pdf',bbox_inches='tight')
plt.show()

# %%
lsaMZApRODataDB3C4
# Out:
# array([[  1.00000000e-02,  -2.00000000e-02,  -1.00000000e-02,
#           0.00000000e+00],
#        [ -1.58428914e+01,  -5.70593637e-01,  -5.07947285e-01,
#           0.00000000e+00],
#        [  2.25527941e-02,   4.92445851e-01,   6.35005467e-01,
#           1.00000000e-01]])

# %%
spectDB3C4DRDBMZApPlt,  spectDB3C4DRDBMZApPltax = plt.subplots()
plt.plot(spectDB3C4DRDBMZAPltData[0],spectDB3C4DRDBMZAPltData[1],'.k')
db3c4seg = 1;
lsaMZApRODataDB3C4Plt =plt.scatter(lsaMZApRODataDB3C4[1][::db3c4seg],lsaMZApRODataDB3C4[0][::db3c4seg], c=lsaMZApRODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZApRODataDB3C4Plt)
plt.xlim([-2,0])
plt.ylim([-2,1])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3C4DRDBMZApPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3C4DRDBMZAmPlt,  spectDB3C4DRDBMZAmPltax = plt.subplots()
plt.plot(spectDB3C4DRDBMZAPltData[0],spectDB3C4DRDBMZAPltData[1],'.k')
db3c4seg = 3;
lsaMZAmRODataDB3C4Plt =plt.scatter(lsaMZAmRODataDB3C4[1][::db3c4seg],lsaMZAmRODataDB3C4[0][::db3c4seg], c=lsaMZAmRODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZAmRODataDB3C4Plt)
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3C4DRDBMZAmPlt.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### WC4

# %%
# C4

spectDB3WC4DRDBMAAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC4DRDBMAAPltData.csv', delimiter=",")  )
spectDB3WC4DRDBMZAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC4DRDBMZAPltData.csv', delimiter=",")  )
lsaMAARODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMAARODataDB3WC4.csv', delimiter=",")  )
lsaMZApRODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZApRODataDB3WC4.csv', delimiter=",")  )
lsaMZAmRODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZAmRODataDB3WC4.csv', delimiter=",")  )

# %%
spectDB3WC4DRDBMAAPlt,  spectDB3WC4DRDBMAAPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMAAPltData[0],spectDB3WC4DRDBMAAPltData[1],'.k')
db3c4seg = 1;
lsaMAARODataDB3WC4Plt =plt.scatter(lsaMAARODataDB3WC4[1][::db3c4seg],lsaMAARODataDB3WC4[0][::db3c4seg], c=lsaMAARODataDB3WC4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataDB3WC4Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-3,3])
plt.ylim([-3,3])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC4DRDBMAAPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3WC4DRDBMZApPlt,  spectDB3WC4DRDBMZApPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMZAPltData[0],spectDB3WC4DRDBMZAPltData[1],'.k')
db3c4seg = 1;
lsaMZApRODataDB3WC4Plt =plt.scatter(lsaMZApRODataDB3WC4[1][::db3c4seg],lsaMZApRODataDB3WC4[0][::db3c4seg], c=lsaMZApRODataDB3WC4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZApRODataDB3WC4Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-3,3])
plt.ylim([-3,3])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC4DRDBMZApPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3WC4DRDBMZAmPlt,  spectDB3WC4DRDBMZAmPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMZAPltData[0],spectDB3WC4DRDBMZAPltData[1],'.k')
db3c4seg = 1;
lsaMZAmRODataDB3WC4Plt =plt.scatter(lsaMZAmRODataDB3WC4[1][::db3c4seg],lsaMZAmRODataDB3WC4[0][::db3c4seg], c=lsaMZAmRODataDB3WC4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZAmRODataDB3WC4Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-1,0])
plt.ylim([-0.25,0.25])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC4DRDBMZAmPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3WC4DRDBMZAPlt,  spectDB3WC4DRDBMZAPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMZAPltData[0],spectDB3WC4DRDBMZAPltData[1],'.k')
db3c4seg = 1;
lsaMZAmRODataDB3WC4Plt =plt.scatter(lsaMZAmRODataDB3WC4[1][::db3c4seg],lsaMZAmRODataDB3WC4[0][::db3c4seg], c=lsaMZAmRODataDB3WC4[2][::db3c4seg], s=lsaPTS, vmin=0,vmax=2.5, cmap=CBAR, edgecolors='none')
lsaMZApRODataDB3WC4Plt =plt.scatter(lsaMZApRODataDB3WC4[1][::db3c4seg],lsaMZApRODataDB3WC4[0][::db3c4seg], c=lsaMZApRODataDB3WC4[2][::db3c4seg], s=lsaPTS, vmin=0,vmax=2.5, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMZApRODataDB3WC4Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-3,3])
plt.ylim([-3,3])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
# plt.savefig('../assets/spectDB3WC4DRDBMZAPlt.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Box Spectrum

# %% [markdown]
# ```
# spectWC1 = {{{-1, -0.3}, 1}, {{-0.3, 1}, 1}};
# spectWC2 = {{{-1, -0.3}, 0.5}, {{-0.3, 1}, 1}};
# spectWC3 = {{{-1, -0.3}, 0.1}, {{-0.3, 1}, 1}};
# spectWC4 = {{{-1, -0.3}, 0}, {{-0.3, 1}, 1}};
#
# spectC1 = {{{-1, -0.3}, -0.1}, {{-0.3, 1}, 1}};
# spectC2 = {{{-1, -0.3}, -0.5}, {{-0.3, 1}, 1}};
# spectC3 = {{{-1, -0.3}, -1}, {{-0.3, 1}, 1}};
# spectC4 = {{{-1, -0.3}, -1.5}, {{-0.3, 1}, 1}};
#
# spectC5 = {{{-1, -0.3}, -15}, {{-0.3, 1}, 1}};
# spectC6 = {{{-1, -0.3}, -0.01}, {{-0.3, 1}, 1}};
# spectC7 = {{{-1, -0.3}, 0.01}, {{-0.3, 1}, 1}};
# spectWC5 = {{{0.1, 0.3}, 1}, {{0.3, 1}, 1}};
# ```

# %% [markdown]
# ### C1

# %%
# %%bash
# ls data/dr-cont-box
# Out:
# maalsadataC1Clean.csv
# pltDRMAADataC1.csv

# %%
spectBoxC1MAADRData = np.transpose( np.genfromtxt ('data/dr-cont-box/pltDRMAADataC1.csv', delimiter=",")  )
lsaMAARODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-cont-box/maalsadataC1Clean.csv', delimiter=",")  )

# %%
spectBoxC1MAADRPlt,  spectBoxC1MAADRDataPltax = plt.subplots()
plt.plot(np.arange(-10,10,0.01),np.arange(-10,10,0.01) , '--', color='0.5' )
plt.plot(np.arange(-10,10,0.01), -np.arange(-10,10,0.01) , '--' , color='0.5'  )
plt.plot(spectBoxC1MAADRData[0],spectBoxC1MAADRData[1],'-k')
db3c4seg = 1;
lsaMAARODataBoxC1Plt =plt.scatter(lsaMAARODataBoxC1[1][::db3c4seg],lsaMAARODataBoxC1[0][::db3c4seg], c=lsaMAARODataBoxC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataBoxC1Plt)
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectBoxC1MAADRPlt.pdf',bbox_inches='tight')
plt.show()

# %%
spectBoxC1u = np.linspace(-1, 1, 10000)

spectBoxC1Spectrum, spectBoxC1Spectrumax = plt.subplots()
plt.plot( spectBoxC1u, np.piecewise(spectBoxC1u, [spectBoxC1u < -0.3, spectBoxC1u >= -0.3], [-0.1, 1]) )
plt.xlabel('$u$')
plt.ylabel('$g$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectBoxC1Spectrum.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Garching Data

# %% [markdown]
# The results are calculated using script
#
# ```
# neuphysics/codebase/mma/dispersion-relation/garching-scripts/dr-garching-spectrum-01.m
# ```
#
# or
#
# ```
# neuphysics/codebase/mma/dispersion-relation/garching-scripts/dr-garching-spectrum.m
# ```
#
# depending on the stepsize used

# %%
spectGarchingMAADRData = np.transpose( np.genfromtxt ('data/dr-garching/okMAAdata-garching-01.csv', delimiter=",")  )
spectGarchingMZApDRData = np.transpose( np.genfromtxt ('data/dr-garching/okMZApdata-garching-01.csv', delimiter=",")  )
spectGarchingMZAmDRData = np.transpose( np.genfromtxt ('data/dr-garching/okMZAmdata-garching-01.csv', delimiter=",")  )

lsaMAARODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/maalsadata-garching-01-clean.csv', delimiter=",")  )
lsaMZApRODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/mzaplsadata-garching-01-clean.csv', delimiter=",")  )
lsaMZAmRODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/mzamlsadata-garching-01-clean.csv', delimiter=",")  )

# lsaMAARODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-garching/maalsadataC1Clean.csv', delimiter=",")  )

# %%
spectGarchingMAADRPlt,  spectGarchingMAADRDataPltax = plt.subplots()
plt.plot(np.arange(-10,10,0.01), np.arange(-10,10,0.01) , '--', color='0.5' )
plt.plot(np.arange(-10,10,0.01), -np.arange(-10,10,0.01) , '--' , color='0.5'  )

plt.plot(spectGarchingMAADRData[0], -spectGarchingMAADRData[1],'-k')

plt.plot(spectGarchingMZApDRData[0], -spectGarchingMZApDRData[1],'-r')
plt.plot(spectGarchingMZAmDRData[0], -spectGarchingMZAmDRData[1],'-r')

db3c4seg = 20;
VMAX = 7;

lsaMAARODataGarchingPlt =plt.scatter(lsaMAARODataGarching[1][::db3c4seg],lsaMAARODataGarching[0][::db3c4seg], c=lsaMAARODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0 , vmax = VMAX, cmap=CBAR, edgecolors='none')
plt.colorbar(lsaMAARODataGarchingPlt)

lsaMZApRODataGarchingPlt =plt.scatter(lsaMZApRODataGarching[1][::db3c4seg],lsaMZApRODataGarching[0][::db3c4seg], c=lsaMZApRODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0, vmax = VMAX, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZApRODataGarchingPlt)

lsaMZAmRODataGarchingPlt =plt.scatter(lsaMZAmRODataGarching[1][::db3c4seg],lsaMZAmRODataGarching[0][::db3c4seg], c=lsaMZAmRODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0, vmax = VMAX, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZAmRODataGarchingPlt)


plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-10,10])
plt.ylim([-10,10])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectGarchingDRLSAPlt.pdf',bbox_inches='tight')
plt.show()

# %%
def garchingSpect(u):
    
    return 3.1091047622370787 + 3.948849723450116*u + 13.632133984410414*np.power(u,2) + 29.7701637868053*np.power(u,3) -  225.4418693733076*np.power(u,4) - 633.2956958542956*np.power(u,5) + 2004.4496383988198*np.power(u,6) +    6141.363460150786*np.power(u,7) - 7352.704265944309*np.power(u,8) - 27716.899615370356*np.power(u,9) +    11634.107295351703*np.power(u,10) + 67594.95724260398*np.power(u,11) - 3020.7355985575978*np.power(u,12) -    95880.52468537232*np.power(u,13) - 16046.882567924806*np.power(u,14) + 79560.56837894565*np.power(u,15) +    24007.739039308894*np.power(u,16) - 35942.62467824584*np.power(u,17) - 14192.446695305043*np.power(u,18) +    6845.044976045668*np.power(u,19) + 3178.7833154504706*np.power(u,20)

# %%
uList = np.arange(-1,1,0.001)
gList = garchingSpect(uList)

# %%
spectGarchingPlt,  spectGarchingPltax = plt.subplots()
plt.plot(uList,gList, '-k')
plt.xlabel('$u$')
plt.ylabel('$g$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectGarchingPlt.pdf',bbox_inches='tight')
plt.show()
