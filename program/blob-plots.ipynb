# %% [markdown]
# ## Blob Plots of Dispersion Relations

# %% [markdown]
# A simple transformation that turns the color bar plots into blob plots.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import matplotlib as mpl
from matplotlib import rcParams

mpl.rcParams['figure.figsize'] = (12,12*0.618)

rcParams['font.family'] = 'sans-serif'
#rcParams['font.sans-serif'] = ['Computer Modern Roman']
# Times-Roman

ftsz = 22
lsaPTS = 30
CBAR = 'viridis_r'

# %%
params = {'legend.fontsize': 'x-large',
#           'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
          'xtick.direction':'in',
          'ytick.direction':'in',
         'ytick.labelsize':'x-large',
         'lines.linewidth': '2.5' }
plt.rcParams.update(params)

# %%
print(plt.style.available)
# Out:
# ['_classic_test', 'bmh', 'classic', 'dark_background', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn']

# %%
# plt.style.use('seaborn-ticks') #seaborn-ticks
plt.style.use('seaborn-paper') #seaborn-ticks

# %% [markdown]
# ### Discrete Zenith Angles

# %% [markdown]
# #### 2 Angles

# %%
# %%bash
# ls data/dr-db-two
# Out:
# lsaMAARODataDBWC1.csv
# lsaMZAmRODataDBWC1.csv
# lsaMZApRODataDBWC1.csv
# spectDBC1DRDBMZAPltData-lower.csv
# spectDBC1DRDBMZAPltData-upper.csv
# spectDBC1DRDBPltData-lower.csv
# spectDBC1DRDBPltData-upper.csv
# spectDBWC1DRDBMZAPltData-lower.csv
# spectDBWC1DRDBMZAPltData-upper.csv
# spectDBWC1DRDBPltData-lower.csv
# spectDBWC1DRDBPltData-upper.csv

# %%
# Import data for WC1 spectrum
spectDBWC1DRDBPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBPltData-upper.csv', delimiter=",")  )
spectDBWC1DRDBPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBPltData-lower.csv', delimiter=",")  )

spectDBWC1DRDBMZAPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBMZAPltData-upper.csv', delimiter=",")  )
spectDBWC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBWC1DRDBMZAPltData-lower.csv', delimiter=",")  )

lsaMAARODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMAARODataDBWC1.csv', delimiter=",")  )
lsaMZApRODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZApRODataDBWC1.csv', delimiter=",")  )
lsaMZAmRODataDBWC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZAmRODataDBWC1.csv', delimiter=",")  )

# Import data for C1 spectrum
spectDBC1DRDBPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBPltData-upper.csv', delimiter=",")  )
spectDBC1DRDBPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBPltData-lower.csv', delimiter=",")  )

spectDBC1DRDBMZAPltDataUpper = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBMZAPltData-upper.csv', delimiter=",")  )
spectDBC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBMZAPltData-lower.csv', delimiter=",")  )

lsaMAARODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMAARODataDBC1.csv', delimiter=",")  )
lsaMZApRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZApRODataDBC1.csv', delimiter=",")  )
lsaMZAmRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZAmRODataDBC1.csv', delimiter=",")  )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-ba5428dbe3ba> in <module>()
#      17 spectDBC1DRDBMZAPltDataLower = np.transpose( np.genfromtxt ('data/dr-db-two/spectDBC1DRDBMZAPltData-lower.csv', delimiter=",")  )
#      18
# ---> 19 lsaMAARODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMAARODataDBC1.csv', delimiter=",")  )
#      20 lsaMZApRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZApRODataDBC1.csv', delimiter=",")  )
#      21 lsaMZAmRODataDBC1 = np.transpose( np.genfromtxt ('data/dr-db-two/lsaMZAmRODataDBC1.csv', delimiter=",")  )
#
# ...

# %%
# Generate the boundaries using Re(k)+Im(k) and Re(k)-Im(k)

lsaMZARODataDBWC1 = np.transpose( np.concatenate( (np.transpose( lsaMZApRODataDBWC1) , np.transpose( lsaMZAmRODataDBWC1 ) ), axis =0 )  )

# each element in lsaMZARODataDBWC1 denoted by ele, ele[1] is real part of k, ele[0] is omega, ele[2] is imaginary part of k.

lsaMAARODataDBWC1Blob = []

for ele in np.transpose( lsaMAARODataDBWC1 ):
    lsaMAARODataDBWC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )

lsaMAARODataDBWC1Blob = np.transpose( np.array(lsaMAARODataDBWC1Blob) )

    
lsaMZARODataDBWC1Blob = []

for ele in np.transpose(lsaMZARODataDBWC1):
    lsaMZARODataDBWC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZARODataDBWC1Blob = np.transpose( np.array(lsaMZARODataDBWC1Blob) )

# %%
lsaMAARODataDBWC1.shape,\
lsaMAARODataDBWC1Blob.shape,\
lsaMZApRODataDBWC1.shape, \
lsaMZAmRODataDBWC1.shape, \
lsaMZARODataDBWC1.shape, \
lsaMZARODataDBWC1Blob.shape
# Out:
# ((3, 32), (4, 32), (3, 89), (3, 35), (3, 124), (4, 124))

# %%
spectDBWC1DRDBMAAPlt,  spectDBWC1DRDBMAAPltax = plt.subplots()
db3c4seg =1
# lsaMAARODataDBWC1Plt = plt.scatter(lsaMAARODataDBWC1[1][::db3c4seg],lsaMAARODataDBWC1[0][::db3c4seg], c=lsaMAARODataDBWC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
lsaMAARODataDBWC1Plt = plt.plot(lsaMAARODataDBWC1Blob[1][::db3c4seg],lsaMAARODataDBWC1Blob[0][::db3c4seg],'-r')
lsaMAARODataDBWC1PltP = plt.plot(lsaMAARODataDBWC1Blob[2][::db3c4seg],lsaMAARODataDBWC1Blob[0][::db3c4seg],'--r')
lsaMAARODataDBWC1PltM = plt.plot(lsaMAARODataDBWC1Blob[3][::db3c4seg],lsaMAARODataDBWC1Blob[0][::db3c4seg],'--r')

plt.plot(spectDBWC1DRDBPltDataUpper[0],spectDBWC1DRDBPltDataUpper[1],'-k')
plt.plot(spectDBWC1DRDBPltDataLower[0],spectDBWC1DRDBPltDataLower[1],'-k')


# plt.colorbar(lsaMAARODataDBWC1Plt)
plt.locator_params(nbins=5);
# plt.tick_params(axis='both', direction='in', labelsize='14')
# plt.locator_params(axis='x', nticks=5)
# plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')

# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDBWC1DRDBMAAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
spectDBWC1DRDBMZApPlt,  spectDBWC1DRDBMZApPltax = plt.subplots()
db3c4seg=1
# lsaMZApRODataDBWC1Plt =plt.scatter(lsaMZApRODataDBWC1[1][::db3c4seg],lsaMZApRODataDBWC1[0][::db3c4seg], c=lsaMZApRODataDBWC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZApRODataDBWC1Plt)
lsaMZARODataDBWC1Plt =plt.plot( lsaMZARODataDBWC1Blob[1][::db3c4seg], lsaMZARODataDBWC1Blob[0][::db3c4seg] ,'-r' )
lsaMZARODataDBWC1PltP =plt.plot( lsaMZARODataDBWC1Blob[2][::db3c4seg], lsaMZARODataDBWC1Blob[0][::db3c4seg] ,'--r' )
lsaMZARODataDBWC1PltM =plt.plot( lsaMZARODataDBWC1Blob[3][::db3c4seg], lsaMZARODataDBWC1Blob[0][::db3c4seg] ,'--r' )
# plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')

plt.plot(spectDBWC1DRDBMZAPltDataUpper[0],spectDBWC1DRDBMZAPltDataUpper[1],'-k')
plt.plot(spectDBWC1DRDBMZAPltDataLower[0],spectDBWC1DRDBMZAPltDataLower[1],'-k')


plt.locator_params(nbins=5);
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDBWC1DRDBMZAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 3 Zenith Angles

# %%
# %%bash
# ls data/dr-db-three
# Out:
# lsaMAARODataDB3C4.csv
# lsaMAARODataDB3WC1.csv
# lsaMAARODataDB3WC4.csv
# lsaMZAmRODataDB3C4.csv
# lsaMZAmRODataDB3WC4.csv
# lsaMZApRODataDB3C4.csv
# lsaMZApRODataDB3WC4.csv
# spectDB3C3DRDBPltData.csv
# spectDB3C4DRDBMAAPltData.csv
# spectDB3C4DRDBMZAPltData.csv
# spectDB3WC1DRDBMZAPltData-lower.csv
# spectDB3WC1DRDBMZAPltData-mid.csv
# spectDB3WC1DRDBMZAPltData-upper.csv
# spectDB3WC1DRDBPltData-lower.csv
# spectDB3WC1DRDBPltData-mid.csv
# spectDB3WC1DRDBPltData-upper.csv
# spectDB3WC4DRDBMAAPltData.csv
# spectDB3WC4DRDBMZAPltData.csv

# %%
# C4

spectDB3C4DRDBMAAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3C4DRDBMAAPltData.csv', delimiter=",")  )
spectDB3C4DRDBMZAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3C4DRDBMZAPltData.csv', delimiter=",")  )
lsaMAARODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMAARODataDB3C4.csv', delimiter=",")  )
lsaMZApRODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZApRODataDB3C4.csv', delimiter=",")  )
lsaMZAmRODataDB3C4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZAmRODataDB3C4.csv', delimiter=",")  )

# %%
# Generate the boundaries using Re(k)+Im(k) and Re(k)-Im(k)

lsaMZARODataDB3C4 = np.transpose( np.concatenate( (np.transpose( lsaMZApRODataDB3C4) , np.transpose( lsaMZAmRODataDB3C4 ) ), axis =0 )  )

# each element in lsaMZARODataDBWC1 denoted by ele, ele[1] is real part of k, ele[0] is omega, ele[2] is imaginary part of k.

lsaMAARODataDB3C4Blob = []

for ele in np.transpose( lsaMAARODataDB3C4 ):
    lsaMAARODataDB3C4Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )

lsaMAARODataDB3C4Blob = np.transpose( np.array(lsaMAARODataDB3C4Blob) )

    
lsaMZARODataDB3C4Blob = []

for ele in np.transpose(lsaMZARODataDB3C4):
    lsaMZARODataDB3C4Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZARODataDB3C4Blob = np.transpose( np.array(lsaMZARODataDB3C4Blob) )

# %%
lsaMAARODataDB3C4Blob.shape
# Out:
# (4, 32)

# %%
spectDB3C4DRDBMAAPlt,  spectDB3C4DRDBMAAPltax = plt.subplots()
plt.plot(spectDB3C4DRDBMAAPltData[0],spectDB3C4DRDBMAAPltData[1],'.k')
db3c4seg = 3;
# lsaMAARODataDB3C4Plt =plt.scatter(lsaMAARODataDB3C4[1][::db3c4seg],lsaMAARODataDB3C4[0][::db3c4seg], c=lsaMAARODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMAARODataDB3C4Plt)
lsaMAARODataDB3C4Plt = plt.plot( lsaMAARODataDB3C4Blob[1][::db3c4seg], lsaMAARODataDB3C4Blob[0][::db3c4seg], '-r' )
lsaMAARODataDB3C4PltP = plt.plot( lsaMAARODataDB3C4Blob[2][::db3c4seg], lsaMAARODataDB3C4Blob[0][::db3c4seg], '--r' )
lsaMAARODataDB3C4PltM = plt.plot( lsaMAARODataDB3C4Blob[3][::db3c4seg], lsaMAARODataDB3C4Blob[0][::db3c4seg], '--r' )

plt.locator_params(nbins=5);
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.xlabel('$k$')
plt.ylabel('$\omega$')

# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3C4DRDBMAAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3C4DRDBMZAmPlt,  spectDB3C4DRDBMZAmPltax = plt.subplots()
plt.plot(spectDB3C4DRDBMZAPltData[0],spectDB3C4DRDBMZAPltData[1],'.k')
db3c4seg = 3;
# lsaMZAmRODataDB3C4Plt =plt.scatter(lsaMZAmRODataDB3C4[1][::db3c4seg],lsaMZAmRODataDB3C4[0][::db3c4seg], c=lsaMZAmRODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZAmRODataDB3C4Plt)

lsaMZARODataDB3C4Plt = plt.plot( lsaMZARODataDB3C4Blob[1][1::db3c4seg], lsaMZARODataDB3C4Blob[0][1::db3c4seg] ,'-r' )
lsaMZARODataDB3C4PltP = plt.plot( lsaMZARODataDB3C4Blob[2][1::db3c4seg], lsaMZARODataDB3C4Blob[0][1::db3c4seg], '--r' )
lsaMZARODataDB3C4PltM = plt.plot( lsaMZARODataDB3C4Blob[3][1::db3c4seg], lsaMZARODataDB3C4Blob[0][1::db3c4seg],'--r' )

plt.locator_params(nbins=5);
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
# plt.savefig('../assets/spectDB3C4DRDBMZAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
# WC4

spectDB3WC4DRDBMAAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC4DRDBMAAPltData.csv', delimiter=",")  )
spectDB3WC4DRDBMZAPltData = np.transpose( np.genfromtxt ('data/dr-db-three/spectDB3WC4DRDBMZAPltData.csv', delimiter=",")  )
lsaMAARODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMAARODataDB3WC4.csv', delimiter=",")  )
lsaMZApRODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZApRODataDB3WC4.csv', delimiter=",")  )
lsaMZAmRODataDB3WC4 = np.transpose( np.genfromtxt ('data/dr-db-three/lsaMZAmRODataDB3WC4.csv', delimiter=",")  )

# %%
# Generate the boundaries using Re(k)+Im(k) and Re(k)-Im(k)

lsaMZARODataDB3WC4 = np.transpose( np.concatenate( (np.transpose( lsaMZAmRODataDB3WC4) , np.transpose( lsaMZApRODataDB3WC4 ) ), axis =0 )  )

# each element in lsaMZARODataDBWC1 denoted by ele, ele[1] is real part of k, ele[0] is omega, ele[2] is imaginary part of k.

lsaMAARODataDB3WC4Blob = []

for ele in np.transpose( lsaMAARODataDB3WC4 ):
    lsaMAARODataDB3WC4Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )

lsaMAARODataDB3WC4Blob = np.transpose( np.array(lsaMAARODataDB3WC4Blob) )

    
lsaMZARODataDB3WC4Blob = []

for ele in np.transpose(lsaMZARODataDB3WC4):
    lsaMZARODataDB3WC4Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZARODataDB3WC4Blob = np.transpose( np.array(lsaMZARODataDB3WC4Blob) )

# %%
sliceid1 = [];
sliceid2 = [];
sliceid3 = [];
def slicefun1(x):
    return 0.52*x
def slicefun2(x):
    return -0.01*x

def xvalue(x):
    return spectDB3WC4DRDBMAAPltData[0][x]


for i in np.arange(len(spectDB3WC4DRDBMAAPltData[0])):
#     print(i)

    if (spectDB3WC4DRDBMAAPltData[1][i] > slicefun2( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid1.append(i)
    elif (spectDB3WC4DRDBMAAPltData[1][i] < slicefun1( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid3.append(i)
    elif (  slicefun1( xvalue(i) ) < spectDB3WC4DRDBMAAPltData[1][i] < slicefun2( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid2.append(i)
    elif (spectDB3WC4DRDBMAAPltData[1][i] > slicefun1( xvalue(i)  ) ) and ( xvalue(i) > 0 ):
        sliceid1.append(i)
    elif (spectDB3WC4DRDBMAAPltData[1][i] < slicefun2( xvalue(i)  ) ) and ( xvalue(i) > 0 ):
        sliceid2.append(i)
    elif ( slicefun2( xvalue(i) )  < spectDB3WC4DRDBMAAPltData[1][i] < slicefun1( xvalue(i)  ) ) and ( xvalue(i) > 0.3 ):
        sliceid3.append(i)

        
spectDB3WC4DRDBMAAPltData1 = [ spectDB3WC4DRDBMAAPltData[0][ sliceid1 ], spectDB3WC4DRDBMAAPltData[1][ sliceid1 ] ]
spectDB3WC4DRDBMAAPltData2 = [ spectDB3WC4DRDBMAAPltData[0][ sliceid2 ], spectDB3WC4DRDBMAAPltData[1][ sliceid2 ] ]
spectDB3WC4DRDBMAAPltData3 = [ spectDB3WC4DRDBMAAPltData[0][ sliceid3 ], spectDB3WC4DRDBMAAPltData[1][ sliceid3 ] ]

# %%
spectDB3WC4DRDBMAAPlt,  spectDB3WC4DRDBMAAPltax = plt.subplots()
db3c4seg = 3;
# lsaMAARODataDB3C4Plt =plt.scatter(lsaMAARODataDB3C4[1][::db3c4seg],lsaMAARODataDB3C4[0][::db3c4seg], c=lsaMAARODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMAARODataDB3C4Plt)
lsaMAARODataDB3WC4Plt = plt.plot( lsaMAARODataDB3WC4Blob[1][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '-r' )
lsaMAARODataDB3WC4PltP = plt.plot( lsaMAARODataDB3WC4Blob[2][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '--r' )
lsaMAARODataDB3WC4PltM = plt.plot( lsaMAARODataDB3WC4Blob[3][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '--r' )

plt.plot(spectDB3WC4DRDBMAAPltData1[0],spectDB3WC4DRDBMAAPltData1[1],'-k')
plt.plot(spectDB3WC4DRDBMAAPltData2[0],spectDB3WC4DRDBMAAPltData2[1],'-k')
plt.plot(spectDB3WC4DRDBMAAPltData3[0],spectDB3WC4DRDBMAAPltData3[1],'-k')


plt.locator_params(nbins=5);
plt.xlim([-5,5])
plt.ylim([-4,4])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC4DRDBMAAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
## Compare with the previous plot

spectDB3WC4DRDBMAAPlt,  spectDB3WC4DRDBMAAPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMAAPltData[0],spectDB3WC4DRDBMAAPltData[1],'.k')
db3c4seg = 3;
# lsaMAARODataDB3C4Plt =plt.scatter(lsaMAARODataDB3C4[1][::db3c4seg],lsaMAARODataDB3C4[0][::db3c4seg], c=lsaMAARODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMAARODataDB3C4Plt)
lsaMAARODataDB3WC4Plt = plt.plot( lsaMAARODataDB3WC4Blob[1][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '-r' )
lsaMAARODataDB3WC4PltP = plt.plot( lsaMAARODataDB3WC4Blob[2][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '--r' )
lsaMAARODataDB3WC4PltM = plt.plot( lsaMAARODataDB3WC4Blob[3][::db3c4seg], lsaMAARODataDB3WC4Blob[0][::db3c4seg], '--r' )

plt.locator_params(nbins=5);
plt.xlim([-4,4])
plt.ylim([-4,4])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
plt.show()

# %%
sliceid4 = [];
sliceid5 = [];
sliceid6 = [];
def slicefun3(x):
    return 0.52*x
def slicefun4(x):
    return -0.01*x

def xvalue(x):
    return spectDB3WC4DRDBMZAPltData[0][x]


for i in np.arange(len(spectDB3WC4DRDBMZAPltData[0])):
#     print(i)

    if (spectDB3WC4DRDBMZAPltData[1][i] > slicefun4( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid4.append(i)
    elif (spectDB3WC4DRDBMZAPltData[1][i] < slicefun3( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid6.append(i)
    elif (  slicefun3( xvalue(i) ) < spectDB3WC4DRDBMZAPltData[1][i] < slicefun4( xvalue(i) ) ) and ( xvalue(i) < 0 ):
        sliceid5.append(i)
    elif (spectDB3WC4DRDBMZAPltData[1][i] > slicefun3( xvalue(i)  ) ) and ( xvalue(i) > 0 ):
        sliceid4.append(i)
    elif (spectDB3WC4DRDBMZAPltData[1][i] < slicefun4( xvalue(i)  ) ) and ( xvalue(i) > 0 ):
        sliceid6.append(i)
    elif ( slicefun4( xvalue(i) )  < spectDB3WC4DRDBMZAPltData[1][i] < slicefun3( xvalue(i)  ) ) and ( xvalue(i) > 0 ):
        sliceid5.append(i)

        
spectDB3WC4DRDBMZAPltData1 = [ spectDB3WC4DRDBMZAPltData[0][ sliceid4 ], spectDB3WC4DRDBMZAPltData[1][ sliceid4 ] ]
spectDB3WC4DRDBMZAPltData2 = [ spectDB3WC4DRDBMZAPltData[0][ sliceid5 ], spectDB3WC4DRDBMZAPltData[1][ sliceid5 ] ]
spectDB3WC4DRDBMZAPltData3 = [ spectDB3WC4DRDBMZAPltData[0][ sliceid6 ], spectDB3WC4DRDBMZAPltData[1][ sliceid6 ] ]

# %%
spectDB3WC4DRDBMZAmPlt,  spectDB3WC4DRDBMZAmPltax = plt.subplots()
db3c4seg = 3;
# lsaMZAmRODataDB3C4Plt =plt.scatter(lsaMZAmRODataDB3C4[1][::db3c4seg],lsaMZAmRODataDB3C4[0][::db3c4seg], c=lsaMZAmRODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZAmRODataDB3C4Plt)

lsaMZARODataDB3WC4Plt = plt.plot( lsaMZARODataDB3WC4Blob[1][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg] ,'-r' )
lsaMZARODataDB3WC4PltP = plt.plot( lsaMZARODataDB3WC4Blob[2][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg], '--r' )
lsaMZARODataDB3WC4PltM = plt.plot( lsaMZARODataDB3WC4Blob[3][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg],'--r' )

plt.plot(spectDB3WC4DRDBMZAPltData1[0],spectDB3WC4DRDBMZAPltData1[1],'-k')
plt.plot(spectDB3WC4DRDBMZAPltData2[0],spectDB3WC4DRDBMZAPltData2[1],'-k')
plt.plot(spectDB3WC4DRDBMZAPltData3[0],spectDB3WC4DRDBMZAPltData3[1],'-k')


plt.locator_params(nbins=5);
plt.xlim([-5,5])
plt.ylim([-4,4])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectDB3WC4DRDBMZAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
spectDB3WC4DRDBMZAmPlt,  spectDB3WC4DRDBMZAmPltax = plt.subplots()
plt.plot(spectDB3WC4DRDBMZAPltData[0],spectDB3WC4DRDBMZAPltData[1],'.k')
db3c4seg = 3;
# lsaMZAmRODataDB3C4Plt =plt.scatter(lsaMZAmRODataDB3C4[1][::db3c4seg],lsaMZAmRODataDB3C4[0][::db3c4seg], c=lsaMZAmRODataDB3C4[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMZAmRODataDB3C4Plt)

lsaMZARODataDB3WC4Plt = plt.plot( lsaMZARODataDB3WC4Blob[1][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg] ,'-r' )
lsaMZARODataDB3WC4PltP = plt.plot( lsaMZARODataDB3WC4Blob[2][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg], '--r' )
lsaMZARODataDB3WC4PltM = plt.plot( lsaMZARODataDB3WC4Blob[3][1::db3c4seg], lsaMZARODataDB3WC4Blob[0][1::db3c4seg],'--r' )

plt.locator_params(nbins=5);
plt.xlim([-4,4])
plt.ylim([-4,4])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
# plt.savefig('../assets/spectDB3WC4DRDBMZAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Box Spectra

# %% [markdown]
# #### SpectBoxC1

# %%
# %%bash
# ls data/dr-cont-box
# Out:
# maalsadataC1Clean.csv
# mzamlsadataC1Clean.csv
# mzaplsadataC1Clean.csv
# pltDRMAADataC1.csv
# pltDRMZADataC1.csv
# pltDRMZAmDataC1.csv
# pltDRMZApDataC1.csv

# %%
spectBoxC1MAADRData = np.transpose( np.genfromtxt ('data/dr-cont-box/pltDRMAADataC1.csv', delimiter=",")  )
lsaMAARODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-cont-box/maalsadataC1Clean.csv', delimiter=",")  )

spectBoxC1MZApDRData = np.transpose( np.genfromtxt ('data/dr-cont-box/pltDRMZApDataC1.csv', delimiter=",")  )
spectBoxC1MZAmDRData = np.transpose( np.genfromtxt ('data/dr-cont-box/pltDRMZAmDataC1.csv', delimiter=",")  )
lsaMZApRODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-cont-box/mzaplsadataC1Clean.csv', delimiter=",")  )
lsaMZAmRODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-cont-box/mzamlsadataC1Clean.csv', delimiter=",")  )

spectBoxC1MZADRData = np.transpose( np.genfromtxt ('data/dr-cont-box/pltDRMZADataC1.csv', delimiter=",")  )

# %%
# Generate the boundaries using Re(k)+Im(k) and Re(k)-Im(k)

lsaMZARODataBoxC1 = np.transpose( np.concatenate( (np.transpose( lsaMZApRODataBoxC1) , np.transpose( lsaMZAmRODataBoxC1 ) ), axis =0 )  )

# each element in lsaMZARODataDBWC1 denoted by ele, ele[1] is real part of k, ele[0] is omega, ele[2] is imaginary part of k.

lsaMAARODataBoxC1Blob = []

for ele in np.transpose( lsaMAARODataBoxC1 ):
    lsaMAARODataBoxC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )

# lsaMAARODataBoxC1Blob = np.concatenate(  (np.array([ [lsaMAARODataBoxC1[0][-1] , lsaMAARODataBoxC1[1][-1], lsaMAARODataBoxC1[0][-1], lsaMAARODataBoxC1[0][-1] ]]), np.array( lsaMAARODataBoxC1Blob ) ), axis=0  )

lsaMAARODataBoxC1Blob = np.transpose( np.array(lsaMAARODataBoxC1Blob) )

    
lsaMZARODataBoxC1Blob = []

for ele in np.transpose(lsaMZARODataBoxC1):
    lsaMZARODataBoxC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZARODataBoxC1Blob = np.transpose( np.array(lsaMZARODataBoxC1Blob) )


lsaMZApRODataBoxC1Blob = []

for ele in np.transpose(lsaMZApRODataBoxC1):
    lsaMZApRODataBoxC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
# lsaMZApRODataBoxC1Blob.append( [lsaMZApRODataBoxC1[0][0] , lsaMZApRODataBoxC1[1][0], lsaMZApRODataBoxC1[0][0], lsaMZApRODataBoxC1[0][0] ] )

lsaMZApRODataBoxC1Blob = np.transpose( np.array(lsaMZApRODataBoxC1Blob) )


lsaMZAmRODataBoxC1Blob = []

for ele in np.transpose(lsaMZAmRODataBoxC1):
    lsaMZAmRODataBoxC1Blob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZAmRODataBoxC1Blob = np.transpose( np.array(lsaMZAmRODataBoxC1Blob) )

## The data points actually swaped and I have to swap back the last two elements of the p and m data

lsaMZApRODataBoxC1BlobSwap = []
lsaMZAmRODataBoxC1BlobSwap = []


for ele in np.transpose(lsaMZApRODataBoxC1Blob):
    if ele[3]>ele[1]:
        lsaMZApRODataBoxC1BlobSwap.append( ele )
    else:
        lsaMZApRODataBoxC1BlobSwap.append( [ele[0], ele[1], ele[3], ele[2] ] )


for ele in np.transpose(lsaMZAmRODataBoxC1Blob):
    if ele[3]>ele[1]:
        lsaMZAmRODataBoxC1BlobSwap.append( ele )
    else:
        lsaMZAmRODataBoxC1BlobSwap.append( [ele[0], ele[1], ele[3], ele[2] ] )

        
        
lsaMZApRODataBoxC1BlobSwap = np.transpose( np.array(lsaMZApRODataBoxC1BlobSwap) )
lsaMZAmRODataBoxC1BlobSwap = np.transpose( np.array(lsaMZAmRODataBoxC1BlobSwap) )

# %%
lsaMZApRODataBoxC1BlobSwap.shape, \
lsaMZAmRODataBoxC1BlobSwap.shape, \
lsaMZApRODataBoxC1Blob.shape, \
lsaMZAmRODataBoxC1Blob.shape
# Out:
# ((4, 34), (4, 14), (4, 34), (4, 14))

# %%
lsaMAARODataBoxC1Blob = np.transpose( np.append( np.transpose(lsaMAARODataBoxC1Blob), np.array([[0.191, -0.37, -0.37, -0.37]]), axis=0 ) )

lsaMAARODataBoxC1Blob.shape
# Out:
# (4, 20)

# %%
spectBoxC1MAADRPlt,  spectBoxC1MAADRDataPltax = plt.subplots()
plt.plot(np.arange(-10,10,0.01),np.arange(-10,10,0.01) , '-.', color='0.5' )
plt.plot(np.arange(-10,10,0.01), -np.arange(-10,10,0.01) , '-.' , color='0.5'  )

db3c4seg = 1;
# lsaMAARODataBoxC1Plt =plt.scatter(lsaMAARODataBoxC1[1][::db3c4seg],lsaMAARODataBoxC1[0][::db3c4seg], c=lsaMAARODataBoxC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMAARODataBoxC1Plt)
lsaMAARODataBoxC1Plt = plt.plot( lsaMAARODataBoxC1Blob[1][::db3c4seg],lsaMAARODataBoxC1Blob[0][::db3c4seg] ,'-r' )
lsaMAARODataBoxC1PltP = plt.plot( lsaMAARODataBoxC1Blob[2][::db3c4seg],lsaMAARODataBoxC1Blob[0][::db3c4seg] ,'--r' )
lsaMAARODataBoxC1PltM = plt.plot( lsaMAARODataBoxC1Blob[3][::db3c4seg],lsaMAARODataBoxC1Blob[0][::db3c4seg] , '--r' )

plt.plot(spectBoxC1MAADRData[0],spectBoxC1MAADRData[1],'-k')

plt.locator_params(nbins=5);
plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = '0.5')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectBoxC1MAADRPltBlob.pdf',bbox_inches='tight')
plt.show()

# %%
np.transpose(lsaMZApRODataBoxC1BlobSwap)[:5]
# Out:
# array([[-0.339     ,  0.85696239, -0.08886464,  1.80278942],
#        [-0.329     ,  0.84686762, -0.12806518,  1.82180042],
#        [-0.319     ,  0.83729604, -0.16572294,  1.84031501],
#        [-0.309     ,  0.82817925, -0.20197289,  1.85833139],
#        [-0.299     ,  0.81946113, -0.23693253,  1.87585479]])

# %%
lsaMZApRODataBoxC1BlobSwap = np.transpose( np.insert( np.transpose(lsaMZApRODataBoxC1BlobSwap), 0, np.array([[-0.359, 0.877, 0.877, 0.877], [-0.349, 0.867, -0.05, 1.783]]), axis=0 ) )

lsaMZApRODataBoxC1BlobSwap.shape
# Out:
# (4, 36)

# %%
spectBoxC1MZApDRPlt,  spectBoxC1MZApDRDataPltax = plt.subplots()
plt.plot(np.arange(-10,10,0.01),np.arange(-10,10,0.01) , '-.', color='0.5' )
plt.plot(np.arange(-10,10,0.01), -np.arange(-10,10,0.01) , '-.' , color='0.5'  )

db3c4seg = 1;
# VMAX = 1;

# lsaMZApRODataBoxC1Plt =plt.scatter(lsaMZApRODataBoxC1[1][::db3c4seg],lsaMZApRODataBoxC1[0][::db3c4seg], c=lsaMZApRODataBoxC1[2][::db3c4seg], s=lsaPTS, vmin=0, cmap=CBAR, edgecolors='none')

# lsaMZAmRODataBoxC1Plt =plt.scatter(lsaMZAmRODataBoxC1[1][::db3c4seg],lsaMZAmRODataBoxC1[0][::db3c4seg], c=lsaMZAmRODataBoxC1[2][::db3c4seg], s=lsaPTS, vmin=0, vmax= VMAX, cmap=CBAR, edgecolors='none')

# plt.colorbar(lsaMZApRODataBoxC1Plt)

lsaMZApRODataBoxC1Plt = plt.plot( lsaMZApRODataBoxC1BlobSwap[1][::db3c4seg],  lsaMZApRODataBoxC1BlobSwap[0][::db3c4seg] ,'-r' )
lsaMZApRODataBoxC1PltP = plt.plot( lsaMZApRODataBoxC1BlobSwap[2][::db3c4seg],  lsaMZApRODataBoxC1BlobSwap[0][::db3c4seg] , '--r' )
lsaMZApRODataBoxC1PltM = plt.plot( lsaMZApRODataBoxC1BlobSwap[3][::db3c4seg],  lsaMZApRODataBoxC1BlobSwap[0][::db3c4seg], '--r' )

lsaMZAmRODataBoxC1Plt = plt.plot( lsaMZAmRODataBoxC1BlobSwap[1][::db3c4seg],  lsaMZAmRODataBoxC1BlobSwap[0][::db3c4seg] ,'-r' )
lsaMZAmRODataBoxC1PltP = plt.plot( lsaMZAmRODataBoxC1BlobSwap[2][::db3c4seg],  lsaMZAmRODataBoxC1BlobSwap[0][::db3c4seg] , '--r' )
lsaMZAmRODataBoxC1PltM = plt.plot( lsaMZAmRODataBoxC1BlobSwap[3][::db3c4seg],  lsaMZAmRODataBoxC1BlobSwap[0][::db3c4seg], '--r' )

plt.plot(spectBoxC1MZADRData[0],spectBoxC1MZADRData[1],'-k')


plt.locator_params(nbins=5);

plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = '0.5')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.xlabel('$k$')
plt.ylabel('$\omega$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectBoxC1MZADRPltBlob.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Garching Data

# %%
spectGarchingMAADRData = np.transpose( -np.genfromtxt ('data/dr-garching/okMAAdata-garching-01.csv', delimiter=",")  )
spectGarchingMZApDRData = np.transpose( -np.genfromtxt ('data/dr-garching/okMZApdata-garching-01.csv', delimiter=",")  )
spectGarchingMZAmDRData = np.transpose( -np.genfromtxt ('data/dr-garching/okMZAmdata-garching-01.csv', delimiter=",")  )

lsaMAARODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/maalsadata-garching-01-clean.csv', delimiter=",")  )
lsaMZApRODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/mzaplsadata-garching-01-clean.csv', delimiter=",")  )
lsaMZAmRODataGarching = np.transpose( np.genfromtxt ('data/dr-garching/mzamlsadata-garching-01-clean.csv', delimiter=",")  )

# lsaMAARODataBoxC1 = np.transpose( np.genfromtxt ('data/dr-garching/maalsadataC1Clean.csv', delimiter=",")  )

# %%
# Generate the boundaries using Re(k)+Im(k) and Re(k)-Im(k)


# each element in lsaMZARODataDBWC1 denoted by ele, ele[1] is real part of k, ele[0] is omega, ele[2] is imaginary part of k.

lsaMAARODataGarchingBlob = []

for ele in np.transpose( lsaMAARODataGarching ):
    lsaMAARODataGarchingBlob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )

# lsaMAARODataBoxC1Blob = np.concatenate(  (np.array([ [lsaMAARODataBoxC1[0][-1] , lsaMAARODataBoxC1[1][-1], lsaMAARODataBoxC1[0][-1], lsaMAARODataBoxC1[0][-1] ]]), np.array( lsaMAARODataBoxC1Blob ) ), axis=0  )

lsaMAARODataGarchingBlob = np.transpose( np.array(lsaMAARODataGarchingBlob) )



lsaMZApRODataGarchingBlob = []

for ele in np.transpose(lsaMZApRODataGarching):
    lsaMZApRODataGarchingBlob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
# lsaMZApRODataBoxC1Blob.append( [lsaMZApRODataBoxC1[0][0] , lsaMZApRODataBoxC1[1][0], lsaMZApRODataBoxC1[0][0], lsaMZApRODataBoxC1[0][0] ] )

lsaMZApRODataGarchingBlob = np.transpose( np.array(lsaMZApRODataGarchingBlob) )


lsaMZAmRODataGarchingBlob = []

for ele in np.transpose(lsaMZAmRODataGarching):
    lsaMZAmRODataGarchingBlob.append( [ele[0], ele[1], ele[1]+ele[2], ele[1]-ele[2] ] )
    
lsaMZAmRODataGarchingBlob = np.transpose( np.array(lsaMZAmRODataGarchingBlob) )

## The data points actually swaped and I have to swap back the last two elements of the p and m data

lsaMZApRODataGarchingBlobSwap = []
lsaMZAmRODataGarchingBlobSwap = []


for ele in np.transpose(lsaMZApRODataGarchingBlobSwap):
    if ele[3]>ele[1]:
        lsaMZApRODataGarchingBlobSwap.append( ele )
    else:
        lsaMZApRODataGarchingBlobSwap.append( [ele[0], ele[1], ele[3], ele[2] ] )


for ele in np.transpose(lsaMZAmRODataGarchingBlobSwap):
    if ele[3]>ele[1]:
        lsaMZAmRODataGarchingBlobSwap.append( ele )
    else:
        lsaMZAmRODataGarchingBlobSwap.append( [ele[0], ele[1], ele[3], ele[2] ] )

        
        
lsaMZApRODataGarchingBlobSwap = np.transpose( np.array(lsaMZApRODataGarchingBlobSwap) )
lsaMZAmRODataGarchingBlobSwap = np.transpose( np.array(lsaMZAmRODataGarchingBlobSwap) )

# %%
lsaMZAmRODataGarchingBlob[3],\
lsaMZAmRODataGarchingBlob[2][::-1], \
np.concatenate((lsaMZAmRODataGarchingBlob[3],  lsaMZAmRODataGarchingBlob[2][::-1]) )
# Out:
# (array([-1.79853241, -1.79166078, -1.78469766, -1.77764557, -1.77050705,
#         -1.76328452, -1.75598025, -1.74859638, -1.74113486, -1.73359747,
#         -1.72598584, -1.71830141, -1.71054547, -1.70271914, -1.69482338,
#         -1.686859  , -1.67882668, -1.67072696, -1.66256022, -1.65432676,
#         -1.64602673, -1.63766018, -1.62922704, -1.62072715, -1.61216025,
#         -1.60352598, -1.59482388, -1.58605341, -1.57721395, -1.56830479,
#         -1.55932512, -1.55027408, -1.5411507 , -1.53195395, -1.52268271,
#         -1.51333577, -1.50391187, -1.49440962, -1.4848276 , -1.47516427,
#         -1.465418  , -1.45558711, -1.44566978, -1.43566414, -1.42556819,
#         -1.41537984, -1.4050969 , -1.39471708, -1.38423796, -1.373657  ,
#         -1.36297155, -1.35217883, -1.34127591, -1.33025973, -1.31912707,
#         -1.30787454, -1.2964986 , -1.28499553, -1.27336139, -1.26159206,
#         -1.24968321, -1.23763024, -1.22542834, -1.2130724 , -1.20055704,
# ...

# %%
spectGarchingMAADRPlt,  spectGarchingMAADRDataPltax = plt.subplots()
plt.plot(np.arange(-10,10,0.01), np.arange(-10,10,0.01) , '-.', color='0.5' )
plt.plot(np.arange(-10,10,0.01), -np.arange(-10,10,0.01) , '-.' , color='0.5'  )

plt.plot(spectGarchingMAADRData[0], spectGarchingMAADRData[1],'-r')

plt.plot(spectGarchingMZApDRData[0], spectGarchingMZApDRData[1],'-b')
plt.plot(spectGarchingMZAmDRData[0], spectGarchingMZAmDRData[1],'-g')

db3c4seg = 1;

# lsaMAARODataGarchingPlt =plt.scatter(lsaMAARODataGarching[1][::db3c4seg],lsaMAARODataGarching[0][::db3c4seg], c=lsaMAARODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0 , vmax = VMAX, cmap=CBAR, edgecolors='none')
# plt.colorbar(lsaMAARODataGarchingPlt)

# lsaMZApRODataGarchingPlt =plt.scatter(lsaMZApRODataGarching[1][::db3c4seg],lsaMZApRODataGarching[0][::db3c4seg], c=lsaMZApRODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0, vmax = VMAX, cmap=CBAR, edgecolors='none')
# # plt.colorbar(lsaMZApRODataGarchingPlt)

# lsaMZAmRODataGarchingPlt =plt.scatter(lsaMZAmRODataGarching[1][::db3c4seg],lsaMZAmRODataGarching[0][::db3c4seg], c=lsaMZAmRODataGarching[2][::db3c4seg], s=lsaPTS, vmin=0, vmax = VMAX, cmap=CBAR, edgecolors='none')
# # plt.colorbar(lsaMZAmRODataGarchingPlt)

lsaMAARODataGarchingBlobPMk = np.concatenate((lsaMAARODataGarchingBlob[3], lsaMAARODataGarchingBlob[2][::-1]) )
lsaMAARODataGarchingBlobPMOmega = np.concatenate((lsaMAARODataGarchingBlob[0], lsaMAARODataGarchingBlob[0][::-1]) )

lsaMAARODataGarchingPlt = plt.plot( lsaMAARODataGarchingBlob[1][::db3c4seg], lsaMAARODataGarchingBlob[0][::db3c4seg] ,'-r', alpha=0.4 )
# lsaMAARODataGarchingPltP = plt.plot( lsaMAARODataGarchingBlob[2][::db3c4seg], lsaMAARODataGarchingBlob[0][::db3c4seg] , '--r' )
# lsaMAARODataGarchingPltM = plt.plot( lsaMAARODataGarchingBlob[3][::db3c4seg], lsaMAARODataGarchingBlob[0][::db3c4seg] ,'--r' )
lsaMAARODataGarchingPltPM = plt.plot( lsaMAARODataGarchingBlobPMk[::db3c4seg], lsaMAARODataGarchingBlobPMOmega[::db3c4seg] , '--r', alpha=0.4  )
plt.fill_between(lsaMAARODataGarchingBlobPMk[::db3c4seg], lsaMAARODataGarchingBlobPMOmega[::db3c4seg],0, facecolor='red', alpha=0.3)


lsaMZApRODataGarchingBlobPMk = np.concatenate((lsaMZApRODataGarchingBlob[2][::-1],lsaMZApRODataGarchingBlob[3]) )
lsaMZApRODataGarchingBlobPMOmega = np.concatenate((lsaMZApRODataGarchingBlob[0][::-1], lsaMZApRODataGarchingBlob[0]) )

lsaMZApRODataGarchingPlt = plt.plot( lsaMZApRODataGarchingBlob[1][::db3c4seg], lsaMZApRODataGarchingBlob[0][::db3c4seg] ,'-g', alpha=0.4  )
# lsaMZApRODataGarchingPltP = plt.plot( lsaMZApRODataGarchingBlob[2][::db3c4seg], lsaMZApRODataGarchingBlob[0][::db3c4seg], '--g' )
# lsaMZApRODataGarchingPltM = plt.plot( lsaMZApRODataGarchingBlob[3][::db3c4seg], lsaMZApRODataGarchingBlob[0][::db3c4seg], '--g' )
lsaMZApRODataGarchingPltP = plt.plot( lsaMZApRODataGarchingBlobPMk[::db3c4seg], lsaMZApRODataGarchingBlobPMOmega[::db3c4seg], '--g', alpha=0.4  )
plt.fill_between(lsaMZApRODataGarchingBlobPMk[::db3c4seg], lsaMZApRODataGarchingBlobPMOmega[::db3c4seg],0, facecolor='green', alpha=0.3)

lsaMZAmRODataGarchingBlobPMk = np.concatenate((lsaMZAmRODataGarchingBlob[3], lsaMZAmRODataGarchingBlob[2][::-1]) )
lsaMZAmRODataGarchingBlobPMOmega = np.concatenate((lsaMZAmRODataGarchingBlob[0], lsaMZAmRODataGarchingBlob[0][::-1]) )

lsaMZAmRODataGarchingPlt = plt.plot( lsaMZAmRODataGarchingBlob[1][::db3c4seg], lsaMZAmRODataGarchingBlob[0][::db3c4seg] ,'-b', alpha=0.4  )
# lsaMZAmRODataGarchingPltP = plt.plot( lsaMZAmRODataGarchingBlob[2][::db3c4seg], lsaMZAmRODataGarchingBlob[0][::db3c4seg], '--b' )
# lsaMZAmRODataGarchingPltM = plt.plot( lsaMZAmRODataGarchingBlob[3][::db3c4seg], lsaMZAmRODataGarchingBlob[0][::db3c4seg], '--b' )
lsaMZAmRODataGarchingPltM = plt.plot( lsaMZAmRODataGarchingBlobPMk[::db3c4seg], lsaMZAmRODataGarchingBlobPMOmega[::db3c4seg], '--b', alpha=0.4  )
plt.fill_between(lsaMZAmRODataGarchingBlobPMk[::db3c4seg], lsaMZAmRODataGarchingBlobPMOmega[::db3c4seg],0, facecolor='blue', alpha=0.3)


plt.locator_params(nbins=5);

plt.axhline(y=0, xmin=0, xmax=1, linewidth=1, color = 'k')
plt.xlim([-10,10])
plt.ylim([-10,10])
plt.xlabel('$k(\mathrm{cm}^{-1})$')
plt.ylabel('$\omega(\mathrm{cm}^{-1})$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectGarchingDRLSAPltBlob.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Spectra

# %%
def garchingSpect(u):
    
    return 3.1091047622370787 + 3.948849723450116*u + 13.632133984410414*np.power(u,2) + 29.7701637868053*np.power(u,3) -  225.4418693733076*np.power(u,4) - 633.2956958542956*np.power(u,5) + 2004.4496383988198*np.power(u,6) +    6141.363460150786*np.power(u,7) - 7352.704265944309*np.power(u,8) - 27716.899615370356*np.power(u,9) +    11634.107295351703*np.power(u,10) + 67594.95724260398*np.power(u,11) - 3020.7355985575978*np.power(u,12) -    95880.52468537232*np.power(u,13) - 16046.882567924806*np.power(u,14) + 79560.56837894565*np.power(u,15) +    24007.739039308894*np.power(u,16) - 35942.62467824584*np.power(u,17) - 14192.446695305043*np.power(u,18) +    6845.044976045668*np.power(u,19) + 3178.7833154504706*np.power(u,20)


uList = np.arange(-1,1,0.001)
gList = garchingSpect(uList)

spectGarchingPlt,  spectGarchingPltax = plt.subplots()
plt.plot(uList,gList, '-k')

plt.locator_params(nbins=6);

plt.xlabel('$u$')
plt.ylabel('$g(\mathrm{cm}^{-3})$')
# plt.title('Dispersion Relation and Instabilities for WC1')
plt.savefig('../assets/spectGarchingPlt.pdf',bbox_inches='tight')
plt.show()
